# %%
# Core Pkg
import pandas as pd

df_mob = pd.read_csv("data_mob_2021.csv")
df_inc = pd.read_csv("data_inc_2021.csv")

df = df_mob.merge(right=df_inc, on = ["IncidentNumber", "CalYear", "HourOfCall"], how = "left")

def summarize(df):
     table = pd.DataFrame(index=df.columns, columns=['type_info', 'nb_NaN', '%_NaN', 'nb_unique_values', 'list_unique_values', 'dup', "mean_or_mode", "min", "max", "flag"])
     table.loc[:, 'type_info'] = df.dtypes.values
     table.loc[:, 'nb_NaN'] = df.isna().sum().values
     table.loc[:, '%_NaN'] = df.isna().sum().values / len(df)
     table.loc[:, 'nb_unique_values'] = df.nunique().values
     table.loc[:, 'dup'] = df.duplicated().sum()

     def get_list_unique_values(colonne):
         if colonne.nunique() < 6:
            return colonne.unique()
         else:
             return "***" if colonne.dtypes == "O" else "***"
    
     def get_mean_mode(colonne):
         return colonne.mode()[0] if colonne.dtypes == "O" else round(colonne.mean(), 2)

     def alerts(colonne, thresh_na = 0.25, thresh_balance = 0.8):
           if (colonne.isna().sum()/len(df)) > thresh_na:
                return "***"
           elif colonne.value_counts(normalize=True).values[0] > thresh_balance:
                return "It's imbalanced !"
           else:
                return "Nothing to report"
     table.loc[:, 'list_unique_values'] = df.apply(get_list_unique_values)
     table.loc[:, 'mean_or_mode'] = df.apply(get_mean_mode)
     table.loc[:, 'flag'] = df.apply(alerts)

     return table

# %%
summary = summarize(df)

# %%
summary
# Out:
#                                        type_info  nb_NaN     %_NaN  \
# IncidentNumber                            object       0       0.0
# CalYear                                    int64       0       0.0
# HourOfCall                                 int64       0       0.0
# ResourceMobilisationId                     int64       0       0.0
# Resource_Code                             object       0       0.0
# PerformanceReporting                      object       0       0.0
# DateAndTimeMobilised                      object       0       0.0
# DateAndTimeMobile                         object    1597  0.004185
# DateAndTimeArrived                        object       0       0.0
# TurnoutTimeSeconds                       float64    1606  0.004208
# TravelTimeSeconds                        float64    1609  0.004216
# AttendanceTimeSeconds                      int64       0       0.0
# DateAndTimeLeft                           object     154  0.000404
# DateAndTimeReturned                      float64  381613       1.0
# DeployedFromStation_Code                  object       4   0.00001
# DeployedFromStation_Name                  object       4   0.00001
# DeployedFromLocation                      object     358  0.000938
# PumpOrder                                  int64       0       0.0
# PlusCode_Code                             object       0       0.0
# PlusCode_Description                      object       0       0.0
# DelayCodeId                              float64  289690   0.75912
# DelayCode_Description                     object  289690   0.75912
# DateOfCall                                object    1608  0.004214
# TimeOfCall                                object    1608  0.004214
# IncidentGroup                             object    1608  0.004214
# StopCodeDescription                       object    1608  0.004214
# SpecialServiceType                        object  289314  0.758135
# PropertyCategory                          object    1608  0.004214
# PropertyType                              object    1608  0.004214
# AddressQualifier                          object    1608  0.004214
# Postcode_full                             object  237682  0.622835
# Postcode_district                         object    1608  0.004214
# UPRN                                     float64    1608  0.004214
# USRN                                     float64    1608  0.004214
# IncGeo_BoroughCode                        object    1608  0.004214
# IncGeo_BoroughName                        object    1608  0.004214
# ProperCase                                object    1608  0.004214
# IncGeo_WardCode                           object    1612  0.004224
# IncGeo_WardName                           object    1612  0.004224
# IncGeo_WardNameNew                        object    1612  0.004224
# Easting_m                                float64  237682  0.622835
# Northing_m                               float64  237682  0.622835
# Easting_rounded                          float64    1608  0.004214
# Northing_rounded                         float64    1608  0.004214
# Latitude                                 float64  237682  0.622835
# Longitude                                float64  237682  0.622835
# FRS                                       object    1608  0.004214
# IncidentStationGround                     object    1610  0.004219
# FirstPumpArriving_AttendanceTime         float64    1609  0.004216
# FirstPumpArriving_DeployedFromStation     object    1614  0.004229
# SecondPumpArriving_AttendanceTime        float64  156016  0.408833
# SecondPumpArriving_DeployedFromStation    object  156020  0.408844
# NumStationsWithPumpsAttending            float64    1608  0.004214
# NumPumpsAttending                        float64    1608  0.004214
# PumpCount                                float64    1608  0.004214
# PumpHoursRoundUp                         float64    1690  0.004429
# Notional Cost (£)                        float64    1690  0.004429
# NumCalls                                 float64    1608  0.004214
#
#                                        nb_unique_values  \
# IncidentNumber                                   248585
# CalYear                                               3
# HourOfCall                                           24
# ResourceMobilisationId                           381613
# Resource_Code                                       142
# PerformanceReporting                                  3
# DateAndTimeMobilised                             254842
# DateAndTimeMobile                                376335
# DateAndTimeArrived                               378983
# TurnoutTimeSeconds                                  641
# TravelTimeSeconds                                  1150
# AttendanceTimeSeconds                              1201
# DateAndTimeLeft                                  379120
# DateAndTimeReturned                                   0
# DeployedFromStation_Code                            108
# DeployedFromStation_Name                            108
# DeployedFromLocation                                  2
# PumpOrder                                            13
# PlusCode_Code                                         1
# PlusCode_Description                                  1
# DelayCodeId                                          10
# DelayCode_Description                                10
# DateOfCall                                          820
# TimeOfCall                                        78466
# IncidentGroup                                         3
# StopCodeDescription                                   9
# SpecialServiceType                                   20
# PropertyCategory                                      9
# PropertyType                                        283
# AddressQualifier                                     11
# Postcode_full                                     42593
# Postcode_district                                   302
# UPRN                                              67508
# USRN                                              36241
# IncGeo_BoroughCode                                   33
# IncGeo_BoroughName                                   33
# ProperCase                                           33
# IncGeo_WardCode                                     735
# IncGeo_WardName                                    1282
# IncGeo_WardNameNew                                 1282
# Easting_m                                         36778
# Northing_m                                        29935
# Easting_rounded                                     562
# Northing_rounded                                    442
# Latitude                                          98919
# Longitude                                         98956
# FRS                                                   1
# IncidentStationGround                               102
# FirstPumpArriving_AttendanceTime                   1183
# FirstPumpArriving_DeployedFromStation               103
# SecondPumpArriving_AttendanceTime                  1181
# SecondPumpArriving_DeployedFromStation              102
# NumStationsWithPumpsAttending                         9
# NumPumpsAttending                                    11
# PumpCount                                            61
# PumpHoursRoundUp                                    142
# Notional Cost (£)                                   245
# NumCalls                                             59
#
#                                                                list_unique_values  \
# IncidentNumber                                                                ***
# CalYear                                                        [2021, 2022, 2023]
# HourOfCall                                                                    ***
# ResourceMobilisationId                                                        ***
# Resource_Code                                                                 ***
# PerformanceReporting                                             [1, 2, Not Used]
# DateAndTimeMobilised                                                          ***
# DateAndTimeMobile                                                             ***
# DateAndTimeArrived                                                            ***
# TurnoutTimeSeconds                                                            ***
# TravelTimeSeconds                                                             ***
# AttendanceTimeSeconds                                                         ***
# DateAndTimeLeft                                                               ***
# DateAndTimeReturned                                                         [nan]
# DeployedFromStation_Code                                                      ***
# DeployedFromStation_Name                                                      ***
# DeployedFromLocation                           [Home Station, Other Station, nan]
# PumpOrder                                                                     ***
# PlusCode_Code                                                           [Initial]
# PlusCode_Description                                       [Initial Mobilisation]
# DelayCodeId                                                                   ***
# DelayCode_Description                                                         ***
# DateOfCall                                                                    ***
# TimeOfCall                                                                    ***
# IncidentGroup                           [False Alarm, Fire, Special Service, nan]
# StopCodeDescription                                                           ***
# SpecialServiceType                                                            ***
# PropertyCategory                                                              ***
# PropertyType                                                                  ***
# AddressQualifier                                                              ***
# Postcode_full                                                                 ***
# Postcode_district                                                             ***
# UPRN                                                                          ***
# USRN                                                                          ***
# IncGeo_BoroughCode                                                            ***
# IncGeo_BoroughName                                                            ***
# ProperCase                                                                    ***
# IncGeo_WardCode                                                               ***
# IncGeo_WardName                                                               ***
# IncGeo_WardNameNew                                                            ***
# Easting_m                                                                     ***
# Northing_m                                                                    ***
# Easting_rounded                                                               ***
# Northing_rounded                                                              ***
# Latitude                                                                      ***
# Longitude                                                                     ***
# FRS                                                                 [London, nan]
# IncidentStationGround                                                         ***
# FirstPumpArriving_AttendanceTime                                              ***
# FirstPumpArriving_DeployedFromStation                                         ***
# SecondPumpArriving_AttendanceTime                                             ***
# SecondPumpArriving_DeployedFromStation                                        ***
# NumStationsWithPumpsAttending                                                 ***
# NumPumpsAttending                                                             ***
# PumpCount                                                                     ***
# PumpHoursRoundUp                                                              ***
# Notional Cost (£)                                                             ***
# NumCalls                                                                      ***
#
#                                        dup  \
# IncidentNumber                           0
# CalYear                                  0
# HourOfCall                               0
# ResourceMobilisationId                   0
# Resource_Code                            0
# PerformanceReporting                     0
# DateAndTimeMobilised                     0
# DateAndTimeMobile                        0
# DateAndTimeArrived                       0
# TurnoutTimeSeconds                       0
# TravelTimeSeconds                        0
# AttendanceTimeSeconds                    0
# DateAndTimeLeft                          0
# DateAndTimeReturned                      0
# DeployedFromStation_Code                 0
# DeployedFromStation_Name                 0
# DeployedFromLocation                     0
# PumpOrder                                0
# PlusCode_Code                            0
# PlusCode_Description                     0
# DelayCodeId                              0
# DelayCode_Description                    0
# DateOfCall                               0
# TimeOfCall                               0
# IncidentGroup                            0
# StopCodeDescription                      0
# SpecialServiceType                       0
# PropertyCategory                         0
# PropertyType                             0
# AddressQualifier                         0
# Postcode_full                            0
# Postcode_district                        0
# UPRN                                     0
# USRN                                     0
# IncGeo_BoroughCode                       0
# IncGeo_BoroughName                       0
# ProperCase                               0
# IncGeo_WardCode                          0
# IncGeo_WardName                          0
# IncGeo_WardNameNew                       0
# Easting_m                                0
# Northing_m                               0
# Easting_rounded                          0
# Northing_rounded                         0
# Latitude                                 0
# Longitude                                0
# FRS                                      0
# IncidentStationGround                    0
# FirstPumpArriving_AttendanceTime         0
# FirstPumpArriving_DeployedFromStation    0
# SecondPumpArriving_AttendanceTime        0
# SecondPumpArriving_DeployedFromStation   0
# NumStationsWithPumpsAttending            0
# NumPumpsAttending                        0
# PumpCount                                0
# PumpHoursRoundUp                         0
# Notional Cost (£)                        0
# NumCalls                                 0
#
#                                                                              mean_or_mode  \
# IncidentNumber                                                            053666-07052021
# CalYear                                                                           2021.69
# HourOfCall                                                                          13.33
# ResourceMobilisationId                                                         6049332.78
# Resource_Code                                                                        A231
# PerformanceReporting                                                                    1
# DateAndTimeMobilised                                                  04/11/2021 16:12:10
# DateAndTimeMobile                                                     03/07/2022 13:09:40
# DateAndTimeArrived                                                    14/11/2022 01:53:04
# TurnoutTimeSeconds                                                                   73.0
# TravelTimeSeconds                                                                  281.33
# AttendanceTimeSeconds                                                              353.34
# DateAndTimeLeft                                                       10/06/2021 10:50:08
# DateAndTimeReturned                                                                   NaN
# DeployedFromStation_Code                                                              A24
# DeployedFromStation_Name                                                             Soho
# DeployedFromLocation                                                         Home Station
# PumpOrder                                                                            1.54
# PlusCode_Code                                                                     Initial
# PlusCode_Description                                                 Initial Mobilisation
# DelayCodeId                                                                         10.61
# DelayCode_Description                                                         Not held up
# DateOfCall                                                                    19 Dec 2022
# TimeOfCall                                                                       13:27:08
# IncidentGroup                                                                 False Alarm
# StopCodeDescription                                                                   AFA
# SpecialServiceType                                                   Effecting entry/exit
# PropertyCategory                                                                 Dwelling
# PropertyType                            Purpose Built Flats/Maisonettes - 4 to 9 storeys
# AddressQualifier                                                Correct incident location
# Postcode_full                                                                     E13 8SL
# Postcode_district                                                                     CR0
# UPRN                                                                       16417458538.83
# USRN                                                                          20393308.14
# IncGeo_BoroughCode                                                              E09000033
# IncGeo_BoroughName                                                            WESTMINSTER
# ProperCase                                                                    Westminster
# IncGeo_WardCode                                                                 E05013808
# IncGeo_WardName                                                                  West End
# IncGeo_WardNameNew                                                               West End
# Easting_m                                                                       530654.36
# Northing_m                                                                      180332.55
# Easting_rounded                                                                  530576.6
# Northing_rounded                                                                180404.56
# Latitude                                                                            51.31
# Longitude                                                                           -0.12
# FRS                                                                                London
# IncidentStationGround                                                          Paddington
# FirstPumpArriving_AttendanceTime                                                   306.71
# FirstPumpArriving_DeployedFromStation                                                Soho
# SecondPumpArriving_AttendanceTime                                                  390.32
# SecondPumpArriving_DeployedFromStation                                               Soho
# NumStationsWithPumpsAttending                                                        1.86
# NumPumpsAttending                                                                    2.09
# PumpCount                                                                            2.18
# PumpHoursRoundUp                                                                     1.61
# Notional Cost (£)                                                                  574.18
# NumCalls                                                                             1.37
#
#                                         min  max               flag
# IncidentNumber                          NaN  NaN  Nothing to report
# CalYear                                 NaN  NaN  Nothing to report
# HourOfCall                              NaN  NaN  Nothing to report
# ResourceMobilisationId                  NaN  NaN  Nothing to report
# Resource_Code                           NaN  NaN  Nothing to report
# PerformanceReporting                    NaN  NaN  Nothing to report
# DateAndTimeMobilised                    NaN  NaN  Nothing to report
# DateAndTimeMobile                       NaN  NaN  Nothing to report
# DateAndTimeArrived                      NaN  NaN  Nothing to report
# TurnoutTimeSeconds                      NaN  NaN  Nothing to report
# TravelTimeSeconds                       NaN  NaN  Nothing to report
# AttendanceTimeSeconds                   NaN  NaN  Nothing to report
# DateAndTimeLeft                         NaN  NaN  Nothing to report
# DateAndTimeReturned                     NaN  NaN                ***
# DeployedFromStation_Code                NaN  NaN  Nothing to report
# DeployedFromStation_Name                NaN  NaN  Nothing to report
# DeployedFromLocation                    NaN  NaN  It's imbalanced !
# PumpOrder                               NaN  NaN  Nothing to report
# PlusCode_Code                           NaN  NaN  It's imbalanced !
# PlusCode_Description                    NaN  NaN  It's imbalanced !
# DelayCodeId                             NaN  NaN                ***
# DelayCode_Description                   NaN  NaN                ***
# DateOfCall                              NaN  NaN  Nothing to report
# TimeOfCall                              NaN  NaN  Nothing to report
# IncidentGroup                           NaN  NaN  Nothing to report
# StopCodeDescription                     NaN  NaN  Nothing to report
# SpecialServiceType                      NaN  NaN                ***
# PropertyCategory                        NaN  NaN  Nothing to report
# PropertyType                            NaN  NaN  Nothing to report
# AddressQualifier                        NaN  NaN  Nothing to report
# Postcode_full                           NaN  NaN                ***
# Postcode_district                       NaN  NaN  Nothing to report
# UPRN                                    NaN  NaN  Nothing to report
# USRN                                    NaN  NaN  Nothing to report
# IncGeo_BoroughCode                      NaN  NaN  Nothing to report
# IncGeo_BoroughName                      NaN  NaN  Nothing to report
# ProperCase                              NaN  NaN  Nothing to report
# IncGeo_WardCode                         NaN  NaN  Nothing to report
# IncGeo_WardName                         NaN  NaN  Nothing to report
# IncGeo_WardNameNew                      NaN  NaN  Nothing to report
# Easting_m                               NaN  NaN                ***
# Northing_m                              NaN  NaN                ***
# Easting_rounded                         NaN  NaN  Nothing to report
# Northing_rounded                        NaN  NaN  Nothing to report
# Latitude                                NaN  NaN                ***
# Longitude                               NaN  NaN                ***
# FRS                                     NaN  NaN  It's imbalanced !
# IncidentStationGround                   NaN  NaN  Nothing to report
# FirstPumpArriving_AttendanceTime        NaN  NaN  Nothing to report
# FirstPumpArriving_DeployedFromStation   NaN  NaN  Nothing to report
# SecondPumpArriving_AttendanceTime       NaN  NaN                ***
# SecondPumpArriving_DeployedFromStation  NaN  NaN                ***
# NumStationsWithPumpsAttending           NaN  NaN  Nothing to report
# NumPumpsAttending                       NaN  NaN  Nothing to report
# PumpCount                               NaN  NaN  Nothing to report
# PumpHoursRoundUp                        NaN  NaN  Nothing to report
# Notional Cost (£)                       NaN  NaN  Nothing to report
# NumCalls                                NaN  NaN  It's imbalanced !

# %%
"""df = merge(df_mob, df_inc)

st.header("Rapport des incidents")
st.dataframe(df_inc.head())
st.write("Il y a", df_inc.shape[0], "lignes et", df_inc.shape[1], "colonnes dans le rapport des Incidents")

st.header("Rapport des mobilisations")
st.dataframe(df_mob.head())
st.write("Il y a", df_mob.shape[0], "lignes et", df_mob.shape[1], "colonnes dans le rapport des Mobilisations")

#Merge
st.header("Merge")
st.dataframe(df.head(), use_container_width = True)

#Description des rapports 'Incident' et 'Mobilisation' après fusion
st.write("Il y a", df.shape[0], "lignes et", df.shape[1], "colonnes dans le jeu de données fusionnées")

@st.cache_data
def summarize(df):
table = pd.DataFrame(index=df.columns, columns=['type_info', 'nb_NaN', '%_NaN', 'nb_unique_values', 'list_unique_values', 'dup', "mean_or_mode", "min", "max", "flag"])
table.loc[:, 'type_info'] = df.dtypes.values
table.loc[:, 'nb_NaN'] = df.isna().sum().values
table.loc[:, '%_NaN'] = df.isna().sum().values / len(df)
table.loc[:, 'nb_unique_values'] = df.nunique().values
table.loc[:, 'dup'] = df.duplicated().sum()

def get_list_unique_values(colonne):
    if colonne.nunique() < 6:
            return colonne.unique()
    else:
            return "Too many categories..." if colonne.dtypes == "O" else "Too many values..."

def get_mean_mode(colonne):
    return colonne.mode()[0] if colonne.dtypes == "O" else colonne.mean()

def alerts(colonne, thresh_na = 0.25, thresh_balance = 0.8):
    if (colonne.isna().sum()/len(df)) > thresh_na:
        return "Too many missing values ! "
    elif colonne.value_counts(normalize=True).values[0] > thresh_balance:
        return "It's imbalanced !"
    else:
        return "Nothing to report"

table.loc[:, 'list_unique_values'] = df.apply(get_list_unique_values)
table.loc[:, 'mean_or_mode'] = df.apply(get_mean_mode)
table.loc[:, 'min'] = df.min() # Affichage de la plus petite valeur
table.loc[:, 'max'] = df.max() # Affichage de la plus grande valeur
table.loc[:, 'flag'] = df.apply(alerts)

return table

summary = summarize(df)


#Résumé
st.header("Résumé")
st.write("Exploration du dataframe avec la fonction personnalisée 'summary'")
summary.rename(columns={summary.columns[0]: 'Variable'},inplace=True)
st.dataframe(summary)

#Tests statistiques
from scipy.stats import chi2_contingency
st.header("Test de khi2 sur les variables 'PropertyCategory' et 'IncidentGroup'")
st.subheader("")
st.write("Hypothèses")
st.write("#H0 : la variable de catégorie d'incident est indépendante du type d'incident")
st.write("#H1 : la variable de catégorie d'incident n'est pas indépendante du type d'incident")
contingency_table = pd.crosstab(df['PropertyCategory'], df['IncidentGroup'])
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
st.write("Résultats du test du chi2 :")
st.write("Valeur du chi2 :", chi2)
st.write("p-value :", p_value)
st.write("Degrés de liberté :", dof)
st.success("Conclusion : p-val très petite (< 0.05) => on rejette H0 et on accepte H1.")

import statsmodels.api as sm
import statsmodels.formula.api as smf
st.subheader("Test ANOVA sur les variables 'IncidentGroup' et 'TurnoutTimeSeconds'")
result = smf.ols('TurnoutTimeSeconds ~ IncidentGroup', data=df).fit()
table = sm.stats.anova_lm(result)
st.write("Tableau ANOVA :")
st.dataframe(table)"""
# Out:
# 'df = merge(df_mob, df_inc)\n\nst.header("Rapport des incidents")\nst.dataframe(df_inc.head())\nst.write("Il y a", df_inc.shape[0], "lignes et", df_inc.shape[1], "colonnes dans le rapport des Incidents")\n\nst.header("Rapport des mobilisations")\nst.dataframe(df_mob.head())\nst.write("Il y a", df_mob.shape[0], "lignes et", df_mob.shape[1], "colonnes dans le rapport des Mobilisations")\n\n#Merge\nst.header("Merge")\nst.dataframe(df.head(), use_container_width = True)\n\n#Description des rapports \'Incident\' et \'Mobilisation\' après fusion\nst.write("Il y a", df.shape[0], "lignes et", df.shape[1], "colonnes dans le jeu de données fusionnées")\n\n@st.cache_data\ndef summarize(df):\ntable = pd.DataFrame(index=df.columns, columns=[\'type_info\', \'nb_NaN\', \'%_NaN\', \'nb_unique_values\', \'list_unique_values\', \'dup\', "mean_or_mode", "min", "max", "flag"])\ntable.loc[:, \'type_info\'] = df.dtypes.values\ntable.loc[:, \'nb_NaN\'] = df.isna().sum().values\ntable.loc[:, \'%_NaN\'] = df.isna().sum().values / len(df)\ntable.loc[:, \'nb_unique_values\'] = df.nunique().values\ntable.loc[:, \'dup\'] = df.duplicated().sum()\n\ndef get_list_unique_values(colonne):\n    if colonne.nunique() < 6:\n            return colonne.unique()\n    else:\n            return "Too many categories..." if colonne.dtypes == "O" else "Too many values..."\n\ndef get_mean_mode(colonne):\n    return colonne.mode()[0] if colonne.dtypes == "O" else colonne.mean()\n\ndef alerts(colonne, thresh_na = 0.25, thresh_balance = 0.8):\n    if (colonne.isna().sum()/len(df)) > thresh_na:\n        return "Too many missing values ! "\n    elif colonne.value_counts(normalize=True).values[0] > thresh_balance:\n        return "It\'s imbalanced !"\n    else:\n        return "Nothing to report"\n\ntable.loc[:, \'list_unique_values\'] = df.apply(get_list_unique_values)\ntable.loc[:, \'mean_or_mode\'] = df.apply(get_mean_mode)\ntable.loc[:, \'min\'] = df.min() # Affichage de la plus petite valeur\ntable.loc[:, \'max\'] = df.max() # Affichage de la plus grande valeur\ntable.loc[:, \'flag\'] = df.apply(alerts)\n\nreturn table\n\nsummary = summarize(df)\n\n\n#Résumé\nst.header("Résumé")\nst.write("Exploration du dataframe avec la fonction personnalisée \'summary\'")\nsummary.rename(columns={summary.columns[0]: \'Variable\'},inplace=True)\nst.dataframe(summary)\n\n#Tests statistiques\nfrom scipy.stats import chi2_contingency\nst.header("Test de khi2 sur les variables \'PropertyCategory\' et \'IncidentGroup\'")\nst.subheader("")\nst.write("Hypothèses")\nst.write("#H0 : la variable de catégorie d\'incident est indépendante du type d\'incident")\nst.write("#H1 : la variable de catégorie d\'incident n\'est pas indépendante du type d\'incident")\ncontingency_table = pd.crosstab(df[\'PropertyCategory\'], df[\'IncidentGroup\'])\nchi2, p_value, dof, expected = chi2_contingency(contingency_table)\nst.write("Résultats du test du chi2 :")\nst.write("Valeur du chi2 :", chi2)\nst.write("p-value :", p_value)\nst.write("Degrés de liberté :", dof)\nst.success("Conclusion : p-val très petite (< 0.05) => on rejette H0 et on accepte H1.")\n\nimport statsmodels.api as sm\nimport statsmodels.formula.api as smf\nst.subheader("Test ANOVA sur les variables \'IncidentGroup\' et \'TurnoutTimeSeconds\'")\nresult = smf.ols(\'TurnoutTimeSeconds ~ IncidentGroup\', data=df).fit()\ntable = sm.stats.anova_lm(result)\nst.write("Tableau ANOVA :")\nst.dataframe(table)'
